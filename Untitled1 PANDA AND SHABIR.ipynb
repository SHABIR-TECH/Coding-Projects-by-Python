# %%
pip install panda
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7239 sha256=30d17f0bf0efd08486a17a92b5a8782719e625195b11ffa4e33629bc7ef43ce3
#   Stored in directory: /root/.cache/pip/wheels/df/5c/39/36f8dae25a1e88d6ec4411dec4a143781e64fdff6897758eec
# Successfully built panda
# ...

# %%
#import library
import pandas

# %%
pandas.__version__
# Out:
# '2.2.2'

# %%
import pandas as pd

# %%
data = {
  "calories" : [420, 380, 390],
  "duration" : [50, 40, 45]
}
# This is a dictionary with list

# %%
print(type(data))
# Out:
# <class 'dict'>

# %%
pd.DataFrame(data)   ## create a dataframe from a dict
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
from google.colab import files
uploaded = files.upload() #import excel file from your pc
# Out:
#      <input type="file" id="files-dfc9bea1-b7d9-4d79-aece-6f8f8a3e0ec0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dfc9bea1-b7d9-4d79-aece-6f8f8a3e0ec0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("student.xlsx")#import file into your notebook. save as df(datafarm)

# %%
df
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %% [markdown]
# `**inspect and explore dataset**`

# %%
df.head()
# return first 5 rows
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.head(3)
# first 3 rows
# Out:
#    id      name  class  mark  gender
# 0   1  John Deo   Four    75  female
# 1   2  Max Ruin  Three    85    male
# 2   3    Arnold  Three    55    male

# %%
df.tail(1)
# last row
# Out:
#     id        name class  mark  gender
# 34  35  Rows Noump   Six    88  female

# %%
df.sample()#its only return 1
# Out:
#     id         name class  mark gender
# 30  31  Marry Toeey  Four    88   male

# %%
df.sample(3)
# Out:
#     id      name  class  mark  gender
# 1    2  Max Ruin  Three    85    male
# 21  22    Reggid  Seven    55  female
# 2    3    Arnold  Three    55    male

# %%
df.shape   # its return how many rows and columns we have    35 rows  and  5 columns
# Out:
# (35, 5)

# %%
df.info()  # give you information about panda file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      35 non-null     int64
#  1   name    34 non-null     object
#  2   class   34 non-null     object
#  3   mark    35 non-null     int64
#  4   gender  33 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.5+ KB

# %%
df.columns # return all names of columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
df.describe()  #information about numeric columns
# Out:
#               id       mark
# count  35.000000  35.000000
# mean   18.000000  74.657143
# std    10.246951  16.401117
# min     1.000000  18.000000
# 25%     9.500000  62.500000
# 50%    18.000000  79.000000
# 75%    26.500000  88.000000
# max    35.000000  96.000000

# %%
#std = standart deviation
#25% of the student has mark 62.5 or less
#50% of the students has mark 79 or less
#this is useful to identify outlier#
#mean	18.000000	74.657143   the average 74.657143

# %%
len(df)
# Out:
# 35

# %%
df.size  # rows * columns     35*5
# Out:
# 175

# %%
df.dtypes
# Out:
# id         int64
# name      object
# class     object
# mark       int64
# gender    object
# dtype: object

# %%
df.isnull()  #its return numbers of missing values
# Out:
#        id   name  class   mark  gender
# 0   False  False  False  False   False
# 1   False  False  False  False   False
# 2   False  False  False  False   False
# 3   False  False  False  False   False
# 4   False  False  False  False   False
# 5   False  False  False  False   False
# 6   False  False  False  False   False
# 7   False  False  False  False   False
# 8   False  False  False  False    True
# 9   False  False  False  False   False
# 10  False  False  False  False   False
# 11  False  False  False  False   False
# 12  False  False  False  False   False
# 13  False  False  False  False   False
# 14  False  False   True  False   False
# 15  False  False  False  False   False
# 16  False  False  False  False   False
# 17  False  False  False  False   False
# 18  False  False  False  False   False
# 19  False  False  False  False   False
# 20  False  False  False  False   False
# 21  False  False  False  False   False
# 22  False  False  False  False   False
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# dtype: bool

# %%
df.duplicated().sum()  # here sum will count the true values
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['id', 'name', 'class', 'mark', 'gender'], dtype='object')

# %%
df[['id', 'name', 'class', 'mark', 'gender']]
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78     NaN
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
# return names only
df["name"]
# Out:
# 0        John Deo
# 1        Max Ruin
# 2          Arnold
# 3      Krish Star
# 4       John Mike
# 5       Alex John
# 6     My John Rob
# 7          Asruid
# 8         Tes Qry
# 9        Big John
# 10         Ronald
# 11          Recky
# 12            Kty
# 13           Bigy
# 14       Tade Row
# 15          Gimmy
# 16          Tumyu
# 17          Honny
# 18          Tinny
# 19         Jackly
# 20     Babby John
# 21         Reggid
# 22          Herod
# 23      Tiddy Now
# 24       Giff Tow
# 25         Crelea
# 26            NaN
# 27      Rojj Base
# 28    Tess Played
# 29      Reppy Red
# 30    Marry Toeey
# 31      Binn Rott
# 32      Kenn Rein
# 33       Gain Toe
# 34     Rows Noump
# Name: name, dtype: object

# %%
df.mark
#this is dot notation. but it may not work if column name is sames as one of keyword in Python.
# Out:
# 0     75
# 1     85
# 2     55
# 3     60
# 4     60
# 5     55
# 6     78
# 7     85
# 8     78
# 9     55
# 10    89
# 11    94
# 12    88
# 13    88
# 14    88
# 15    88
# 16    54
# 17    75
# 18    18
# 19    65
# 20    69
# 21    55
# 22    79
# 23    78
# 24    88
# 25    79
# 26    81
# 27    86
# 28    55
# 29    79
# 30    88
# 31    90
# 32    96
# 33    69
# 34    88
# Name: mark, dtype: int64

# %%
df.class
#erro come because class is reversed keyword
# Out:
#   File "<ipython-input-40-350afe6b7ecd>", line 1
#     df.class
#        ^
# SyntaxError: invalid syntax

# %%
df["class"]
# Out:
# 0      Four
# 1     Three
# 2     Three
# 3      Four
# 4      Four
# 5      Four
# 6     Fifth
# 7      Five
# 8       Six
# 9      Four
# 10      Six
# 11      Six
# 12    Seven
# 13    Seven
# 14      NaN
# 15     Four
# 16      Six
# 17     Five
# 18     Nine
# 19     Nine
# 20     Four
# 21    Seven
# 22    Eight
# 23    Seven
# 24    Seven
# 25    Seven
# 26    Three
# 27    Seven
# 28    Seven
# 29      Six
# 30     Four
# 31    Seven
# 32      Six
# 33    Seven
# 34      Six
# Name: class, dtype: object

# %%
df["class"].head()
# Out:
# 0     Four
# 1    Three
# 2    Three
# 3     Four
# 4     Four
# Name: class, dtype: object

# %%
df["mark"].mean()
#calculate average mark
# Out:
# np.float64(74.65714285714286)

# %%
df["mark"].head().median()
# median mark for first 5 student in this class
# Out:
# 60.0

# %%
df[['name', 'class']]
# Out:
#            name  class
# 0      John Deo   Four
# 1      Max Ruin  Three
# 2        Arnold  Three
# 3    Krish Star   Four
# 4     John Mike   Four
# 5     Alex John   Four
# 6   My John Rob  Fifth
# 7        Asruid   Five
# 8       Tes Qry    Six
# 9      Big John   Four
# 10       Ronald    Six
# 11        Recky    Six
# 12          Kty  Seven
# 13         Bigy  Seven
# 14     Tade Row    NaN
# 15        Gimmy   Four
# 16        Tumyu    Six
# 17        Honny   Five
# 18        Tinny   Nine
# 19       Jackly   Nine
# 20   Babby John   Four
# 21       Reggid  Seven
# 22        Herod  Eight
# 23    Tiddy Now  Seven
# 24     Giff Tow  Seven
# 25       Crelea  Seven
# 26          NaN  Three
# 27    Rojj Base  Seven
# 28  Tess Played  Seven
# 29    Reppy Red    Six
# 30  Marry Toeey   Four
# 31    Binn Rott  Seven
# 32    Kenn Rein    Six
# 33     Gain Toe  Seven
# 34   Rows Noump    Six

# %%
df[["class", "name"]].head()
# you can write only 1 column in slicing method
# if you need to return more than 1 column, include them in a list
# first [] used for slicing
# second[] used for list of the column names
# Out:
#    class        name
# 0   Four    John Deo
# 1  Three    Max Ruin
# 2  Three      Arnold
# 3   Four  Krish Star
# 4   Four   John Mike

# %%
df[[ 'name', 'mark', 'gender']].head(3)
# Out:
#        name  mark  gender
# 0  John Deo    75  female
# 1  Max Ruin    85    male
# 2    Arnold    55    male

# %%
df[[ 'name', 'mark', 'gender']].sample(3)
# Out:
#           name  mark  gender
# 25      Crelea    79    male
# 24    Giff Tow    88    male
# 3   Krish Star    60  female

# %%
df.loc[0:4, "name"]
# [rows to return , column names]
# Out:
# 0      John Deo
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# 4     John Mike
# Name: name, dtype: object

# %%
df.iloc[0:5, 1]
# Out:
# 0      John Deo
# 1      Max Ruin
# 2        Arnold
# 3    Krish Star
# 4     John Mike
# Name: name, dtype: object

# %%
df.head(3)[ ["name", "class"]]  #1) Return name and class of first 3 students
# Out:
#        name  class
# 0  John Deo   Four
# 1  Max Ruin  Three
# 2    Arnold  Three

# %%
df[['mark']].mean()    #2) Return average mark for all students
# Out:
# mark    74.657143
# dtype: float64

# %%
df.sample(3)[["class", "gender"]]   #3) Return 3 sample class and gender of the students
# Out:
#     class  gender
# 13  Seven  female
# 34    Six  female
# 7    Five    male

# %%
df.head()   #4) Return first 5 rows
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %%
df.loc[0:4, ["name", "class"]]   #Use loc #1) Return name and class of first 3 students
# Out:
#          name  class
# 0    John Deo   Four
# 1    Max Ruin  Three
# 2      Arnold  Three
# 3  Krish Star   Four
# 4   John Mike   Four

# %%
df.iloc[0:5, 2]   #Use iloc   #4) Return first 5 rows
# Out:
# 0     Four
# 1    Three
# 2    Three
# 3     Four
# 4     Four
# Name: class, dtype: object

# %%
df[:5]  #Use slicing method #4) Return first 5 rows
# Out:
#    id        name  class  mark  gender
# 0   1    John Deo   Four    75  female
# 1   2    Max Ruin  Three    85    male
# 2   3      Arnold  Three    55    male
# 3   4  Krish Star   Four    60  female
# 4   5   John Mike   Four    60  female

# %% [markdown]
# ![1_dYtynwab99wnMqfgyPUd3w.png](data:image/png;base64,...)

# %%
#loc[rows, columns] if you ignore columns, it will return all columns
#iloc[rows, columns] if you only wrote row number, it will return all columns


#if you dont specify start of the range, it will start from 0.

# %%
# return index 2  and index 27
df.loc[[0,27]]
# Out:
#     id       name  class  mark  gender
# 0    1   John Deo   Four    75  female
# 27  28  Rojj Base  Seven    86  female

# %%
# Return male student?
df[df["gender"]== "male"]
# Out:
#     id         name  class  mark gender
# 1    2     Max Ruin  Three    85   male
# 2    3       Arnold  Three    55   male
# 5    6    Alex John   Four    55   male
# 6    7  My John Rob  Fifth    78   male
# 7    8       Asruid   Five    85   male
# 14  15     Tade Row    NaN    88   male
# 15  16        Gimmy   Four    88   male
# 16  17        Tumyu    Six    54   male
# 17  18        Honny   Five    75   male
# 18  19        Tinny   Nine    18   male
# 22  23        Herod  Eight    79   male
# 23  24    Tiddy Now  Seven    78   male
# 24  25     Giff Tow  Seven    88   male
# 25  26       Crelea  Seven    79   male
# 28  29  Tess Played  Seven    55   male
# 30  31  Marry Toeey   Four    88   male
# 33  34     Gain Toe  Seven    69   male

# %% [markdown]
# ###Filtering data

# %%
# What are the names, class and gender of male student?
df[df["gender"]== "male"][["name", "class", "gender"]]
# Out:
#            name  class gender
# 1      Max Ruin  Three   male
# 2        Arnold  Three   male
# 5     Alex John   Four   male
# 6   My John Rob  Fifth   male
# 7        Asruid   Five   male
# 14     Tade Row    NaN   male
# 15        Gimmy   Four   male
# 16        Tumyu    Six   male
# 17        Honny   Five   male
# 18        Tinny   Nine   male
# 22        Herod  Eight   male
# 23    Tiddy Now  Seven   male
# 24     Giff Tow  Seven   male
# 25       Crelea  Seven   male
# 28  Tess Played  Seven   male
# 30  Marry Toeey   Four   male
# 33     Gain Toe  Seven   male

# %%
df[df["class"]=="Six"]
# Out:
#     id        name class  mark  gender
# 8    9     Tes Qry   Six    78     NaN
# 10  11      Ronald   Six    89  female
# 11  12       Recky   Six    94  female
# 16  17       Tumyu   Six    54    male
# 29  30   Reppy Red   Six    79  female
# 32  33   Kenn Rein   Six    96  female
# 34  35  Rows Noump   Six    88  female

# %%
df[df["mark"]< 52]
# Out:
#     id   name class  mark gender
# 18  19  Tinny  Nine    18   male

# %%
df.loc[df["mark"]< 52]
# Out:
#     id   name class  mark gender
# 18  19  Tinny  Nine    18   male

# %%
#- Return female students with their mark greater than 80
df[(df["gender"]== "female") &(df["mark"] > 80)]
# Out:
#     id        name  class  mark  gender
# 10  11      Ronald    Six    89  female
# 11  12       Recky    Six    94  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 27  28   Rojj Base  Seven    86  female
# 31  32   Binn Rott  Seven    90  female
# 32  33   Kenn Rein    Six    96  female
# 34  35  Rows Noump    Six    88  female

# %%
df.loc[ (df["gender"]=="female") & (df["mark"]>80) ]
# Out:
#     id        name  class  mark  gender
# 10  11      Ronald    Six    89  female
# 11  12       Recky    Six    94  female
# 12  13         Kty  Seven    88  female
# 13  14        Bigy  Seven    88  female
# 27  28   Rojj Base  Seven    86  female
# 31  32   Binn Rott  Seven    90  female
# 32  33   Kenn Rein    Six    96  female
# 34  35  Rows Noump    Six    88  female

# %%
df.loc[ (df["gender"]=="female") & (df["mark"]>80) ].head()
# Out:
#     id       name  class  mark  gender
# 10  11     Ronald    Six    89  female
# 11  12      Recky    Six    94  female
# 12  13        Kty  Seven    88  female
# 13  14       Bigy  Seven    88  female
# 27  28  Rojj Base  Seven    86  female

# %%
# female, mark > 80 and Seven
df.loc[ (df["gender"]=="female") & (df["mark"]>80) & (df["class"]=="Seven") , ["name", "gender"] ]
# Out:
#          name  gender
# 12        Kty  female
# 13       Bigy  female
# 27  Rojj Base  female
# 31  Binn Rott  female

# %%
df[(df["gender"] == "male") | (df["class"]=="Five")]
# Out:
#     id         name  class  mark gender
# 1    2     Max Ruin  Three    85   male
# 2    3       Arnold  Three    55   male
# 5    6    Alex John   Four    55   male
# 6    7  My John Rob  Fifth    78   male
# 7    8       Asruid   Five    85   male
# 14  15     Tade Row    NaN    88   male
# 15  16        Gimmy   Four    88   male
# 16  17        Tumyu    Six    54   male
# 17  18        Honny   Five    75   male
# 18  19        Tinny   Nine    18   male
# 22  23        Herod  Eight    79   male
# 23  24    Tiddy Now  Seven    78   male
# 24  25     Giff Tow  Seven    88   male
# 25  26       Crelea  Seven    79   male
# 28  29  Tess Played  Seven    55   male
# 30  31  Marry Toeey   Four    88   male
# 33  34     Gain Toe  Seven    69   male

# %%
df[['mark']].mean()    # Return average mark for all students
# Out:
# mark    74.657143
# dtype: float64

# %%
df.groupby('gender')['mark'].mean()   #Average mark across male and female students
# Out:
# gender
# female    77.312500
# male      71.588235
# Name: mark, dtype: float64

# %%
df.loc[df["gender"]=="male", "mark"].mean()
# Out:
# np.float64(71.58823529411765)

# %%
df.loc[df["gender"]=="female", "mark"].mean()
# Out:
# np.float64(77.3125)

# %%
 df['mark'].max()        #Max and min mark
# Out:
# 96

# %%
df['mark'].min()
# Out:
# 18

# %%
df.groupby('gender')['mark'].max()  #Max mark for male and female students
# Out:
# gender
# female    96
# male      88
# Name: mark, dtype: int64

# %%
df.loc[df["gender"]=="female", "mark"].max()
# Out:
# 96

# %%
df.loc[df["gender"]=="male", "mark"].min()
# Out:
# 18

# %%
df[df['class'] == 'Five']['mark'].mean()      #Average mark for class 'Five'
# Out:
# np.float64(80.0)

# %%
#Average mark for class 'Six' and male students only
df[(df['class'] == 'Six') & (df['gender'] == 'male')]['mark'].mean()
# Out:
# np.float64(54.0)

# %%
df.loc[df["name"].str.contains("John", na=False)]
#.str will convert Pandas series to string object
# na=False means skip missing values
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 9   10     Big John   Four    55  female
# 20  21   Babby John   Four    69  female

# %%
df.sort_values(by="mark")
# sort results by mark column
# Out:
#     id         name  class  mark  gender
# 18  19        Tinny   Nine    18    male
# 16  17        Tumyu    Six    54    male
# 2    3       Arnold  Three    55    male
# 5    6    Alex John   Four    55    male
# 28  29  Tess Played  Seven    55    male
# 21  22       Reggid  Seven    55  female
# 9   10     Big John   Four    55  female
# 4    5    John Mike   Four    60  female
# 3    4   Krish Star   Four    60  female
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 33  34     Gain Toe  Seven    69    male
# 0    1     John Deo   Four    75  female
# 17  18        Honny   Five    75    male
# 8    9      Tes Qry    Six    78     NaN
# 23  24    Tiddy Now  Seven    78    male
# 6    7  My John Rob  Fifth    78    male
# 22  23        Herod  Eight    79    male
# 29  30    Reppy Red    Six    79  female
# 25  26       Crelea  Seven    79    male
# 26  27          NaN  Three    81     NaN
# 1    2     Max Ruin  Three    85    male
# ...

# %%
df.sort_values(by="name")
# Out:
#     id         name  class  mark  gender
# 5    6    Alex John   Four    55    male
# 2    3       Arnold  Three    55    male
# 7    8       Asruid   Five    85    male
# 20  21   Babby John   Four    69  female
# 9   10     Big John   Four    55  female
# 13  14         Bigy  Seven    88  female
# 31  32    Binn Rott  Seven    90  female
# 25  26       Crelea  Seven    79    male
# 33  34     Gain Toe  Seven    69    male
# 24  25     Giff Tow  Seven    88    male
# 15  16        Gimmy   Four    88    male
# 22  23        Herod  Eight    79    male
# 17  18        Honny   Five    75    male
# 19  20       Jackly   Nine    65  female
# 0    1     John Deo   Four    75  female
# 4    5    John Mike   Four    60  female
# 32  33    Kenn Rein    Six    96  female
# 3    4   Krish Star   Four    60  female
# 12  13          Kty  Seven    88  female
# 30  31  Marry Toeey   Four    88    male
# 1    2     Max Ruin  Three    85    male
# 6    7  My John Rob  Fifth    78    male
# ...

# %%
df.loc[:, "name"].sort_values()
# you can ignore by argument if there is only 1 column in the output
# Out:
# 5       Alex John
# 2          Arnold
# 7          Asruid
# 20     Babby John
# 9        Big John
# 13           Bigy
# 31      Binn Rott
# 25         Crelea
# 33       Gain Toe
# 24       Giff Tow
# 15          Gimmy
# 22          Herod
# 17          Honny
# 19         Jackly
# 0        John Deo
# 4       John Mike
# 32      Kenn Rein
# 3      Krish Star
# 12            Kty
# 30    Marry Toeey
# 1        Max Ruin
# 6     My John Rob
# 11          Recky
# 21         Reggid
# 29      Reppy Red
# 27      Rojj Base
# 10         Ronald
# 34     Rows Noump
# 14       Tade Row
# 8         Tes Qry
# 28    Tess Played
# 23      Tiddy Now
# 18          Tinny
# 16          Tumyu
# 26            NaN
# Name: name, dtype: object

# %%
df.loc[1:10, ["name", "class"]].sort_values(by="class")
# Out:
#            name  class
# 6   My John Rob  Fifth
# 7        Asruid   Five
# 3    Krish Star   Four
# 4     John Mike   Four
# 5     Alex John   Four
# 9      Big John   Four
# 8       Tes Qry    Six
# 10       Ronald    Six
# 1      Max Ruin  Three
# 2        Arnold  Three

# %%
df.sort_values(by="mark", ascending=False)
# Out:
#     id         name  class  mark  gender
# 32  33    Kenn Rein    Six    96  female
# 11  12        Recky    Six    94  female
# 31  32    Binn Rott  Seven    90  female
# 10  11       Ronald    Six    89  female
# 30  31  Marry Toeey   Four    88    male
# 34  35   Rows Noump    Six    88  female
# 24  25     Giff Tow  Seven    88    male
# 14  15     Tade Row    NaN    88    male
# 15  16        Gimmy   Four    88    male
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 27  28    Rojj Base  Seven    86  female
# 7    8       Asruid   Five    85    male
# 1    2     Max Ruin  Three    85    male
# 26  27          NaN  Three    81     NaN
# 29  30    Reppy Red    Six    79  female
# 25  26       Crelea  Seven    79    male
# 22  23        Herod  Eight    79    male
# 6    7  My John Rob  Fifth    78    male
# 23  24    Tiddy Now  Seven    78    male
# 8    9      Tes Qry    Six    78     NaN
# 17  18        Honny   Five    75    male
# ...

# %%
df.sort_values(by="mark", ascending=False).head()
# Out:
#     id         name  class  mark  gender
# 32  33    Kenn Rein    Six    96  female
# 11  12        Recky    Six    94  female
# 31  32    Binn Rott  Seven    90  female
# 10  11       Ronald    Six    89  female
# 30  31  Marry Toeey   Four    88    male

# %%
df.loc[:, :].sort_values(by="gender", ascending=False)
# Out:
#     id         name  class  mark  gender
# 17  18        Honny   Five    75    male
# 22  23        Herod  Eight    79    male
# 24  25     Giff Tow  Seven    88    male
# 25  26       Crelea  Seven    79    male
# 18  19        Tinny   Nine    18    male
# 1    2     Max Ruin  Three    85    male
# 16  17        Tumyu    Six    54    male
# 15  16        Gimmy   Four    88    male
# 14  15     Tade Row    NaN    88    male
# 28  29  Tess Played  Seven    55    male
# 23  24    Tiddy Now  Seven    78    male
# 30  31  Marry Toeey   Four    88    male
# 7    8       Asruid   Five    85    male
# 6    7  My John Rob  Fifth    78    male
# 5    6    Alex John   Four    55    male
# 33  34     Gain Toe  Seven    69    male
# 2    3       Arnold  Three    55    male
# 27  28    Rojj Base  Seven    86  female
# 31  32    Binn Rott  Seven    90  female
# 32  33    Kenn Rein    Six    96  female
# 29  30    Reppy Red    Six    79  female
# 0    1     John Deo   Four    75  female
# ...

# %%
## How many male and female students are there?
df["gender"].value_counts()
# how many times male is in the gender
# Out:
# gender
# male      17
# female    16
# Name: count, dtype: int64

# %%
# number of student in each class
df["class"].value_counts()
# Out:
# class
# Seven    10
# Four      8
# Six       7
# Three     3
# Nine      2
# Five      2
# Fifth     1
# Eight     1
# Name: count, dtype: int64
