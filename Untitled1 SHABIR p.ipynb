# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"] # this is a list
print(cust_info)
print(type(cust_info))
# Out:
# ['Yusuf', 'Satilmis', 18, 'UK']
# <class 'list'>

# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"] # this is a list
print(cust_info[0])
print(cust_info[3])
# Out:
# Yusuf
# UK

# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"] # this is a list
print(cust_info[0:3])
# Out:
# ['Yusuf', 'Satilmis', 18]

# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"] # this is a list
print(cust_info[0], cust_info[3])
# Out:
# Yusuf UK

# %%
print(f"first element of the list is {cust_info[0]}.", f"second element is {cust_info[2]}.")
# Out:
# first element of the list is Yusuf. second element is 18.

# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"] # this is a list
print(cust_info)
cust_info[0]=45
print(cust_info)
# Out:
# ['Yusuf', 'Satilmis', 18, 'UK']
# [45, 'Satilmis', 18, 'UK']

# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"] # this is a list
cust_info.append("Leeds")
print(cust_info)
# Out:
# ['Yusuf', 'Satilmis', 18, 'UK', 'Leeds']

# %%
# insert job title at index 4
cust_info.insert(4, "Data Trainer")
print(cust_info)
# Out:
# ['Yusuf', 'Satilmis', 18, 'UK', 'Data Trainer', 'Leeds']

# %%
cust_info.reverse()
cust_info.insert(4, "Data Trainer")
print(cust_info)
# Out:
# ['Leeds', 'Data Trainer', 'UK', 18, 'Data Trainer', 'Satilmis', 'Yusuf']

# %%
cust_info.pop(1)#remove function idex
cust_info.insert(4, "Data Trainer")
print(cust_info)
# Out:
# ['Leeds', 'UK', 18, 'Data Trainer', 'Data Trainer', 'Satilmis', 'Yusuf']

# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"]
cust_info.remove("UK")  # #remove function value
print(cust_info)
# Out:
# ['Yusuf', 'Satilmis', 18]

# %%
mytuple = ("Yusuf", "Satilmis", 18, "UK", True)
print(mytuple)
print(type(mytuple))
# Out:
# ('Yusuf', 'Satilmis', 18, 'UK', True)
# <class 'tuple'>

# %%
import sys

print(mytuple)
print(cust_info)

sys.getsizeof(mytuple)

sys.getsizeof(cust_info)
# Out:
# ('Yusuf', 'Satilmis', 18, 'UK', True)
# ['Yusuf', 'Satilmis', 18]
# 88

# %%
import sys

print(mytuple)
print(cust_info)

sys.getsizeof(mytuple)

sys.getsizeof(cust_info)
print(tuple(mytuple))
# Out:
# ('Yusuf', 'Satilmis', 18, 'UK', True)
# ['Yusuf', 'Satilmis', 18]
# ('Yusuf', 'Satilmis', 18, 'UK', True)

# %%
import sys

print(mytuple)
print(cust_info)

sys.getsizeof(mytuple)

sys.getsizeof(cust_info)
print(mytuple.count("Yusuf"))
print(mytuple.index("UK"))
# Out:
# ('Yusuf', 'Satilmis', 18, 'UK', True)
# ['Yusuf', 'Satilmis', 18]
# 1
# 3

# %%
myset = {'Yusuf', 'Satilmis', 18, 'UK', True, True}
print(myset)
print(type(myset))
# Out:
# {True, 18, 'UK', 'Satilmis', 'Yusuf'}
# <class 'set'>

# %%
mytuple = ("Yusuf", "Satilmis", 18, "UK", True)
sys.getsizeof(mytuple)
# Out:
# 80

# %%
cust_info = ["Yusuf", "Satilmis", 18, "UK"]
sys.getsizeof(cust_info)
# Out:
# 88

# %%
myset = {'Yusuf', 'Satilmis', 18, 'UK', True, True}
sys.getsizeof(myset)
# Out:
# 472

# %%
mydict = {"name": "Yusuf", "surname": "Satilmis", "age": 18, "country": "UK"}
print(mydict)
# Out:
# {'name': 'Yusuf', 'surname': 'Satilmis', 'age': 18, 'country': 'UK'}

# %%
mydict = {"name": "Yusuf", "surname": "Satilmis", "age": 18, "country": "UK"}
print(mydict)
print(type(mydict))
# Out:
# {'name': 'Yusuf', 'surname': 'Satilmis', 'age': 18, 'country': 'UK'}
# <class 'dict'>

# %%
mydict = {"name": "Yusuf", "surname": "Satilmis", "age": 18, "country": "UK"}
keys = mydict.keys()
print(mydict)
print(mydict.values())

print(mydict.keys())

print(mydict.get("name"))
print(mydict.get("country"))
# Out:
# {'name': 'Yusuf', 'surname': 'Satilmis', 'age': 18, 'country': 'UK'}
# dict_values(['Yusuf', 'Satilmis', 18, 'UK'])
# dict_keys(['name', 'surname', 'age', 'country'])
# Yusuf
# UK
